# %% [markdown]
# # GoogLeNet

# %%
import keras
import cv2
import numpy as np
from keras.datasets import cifar10, cifar100
from keras.models import Model
from keras.layers import Input, Dense, Dropout, Activation, Add, Flatten
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from keras.initializers import glorot_uniform
from keras.regularizers import l2
from keras.layers.merge import concatenate
from keras.layers.normalization import BatchNormalization
from keras import optimizers
# Out:
# Using TensorFlow backend.

# %%
c10_class_name = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
c100_class_name = ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 
                   'camel', 'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 
                   'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 
                   'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse','mushroom', 'oak_tree', 'orange', 'orchid', 
                   'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 
                   'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 
                   'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 
                   'willow_tree', 'wolf', 'woman', 'worm']

# %%
def preprocess_image(X, image_height=224, image_width=224):
    X_resize = []
    for i in range(len(X)):
        #X[i] = X[i] / 255.0
        X_resize.append(cv2.resize(X[i], (image_height, image_width)))
    return np.asarray(X_resize)

# %%
def inception_module(X, f1, f2_in, f2_out, f3_in, f3_out, f4_out, stage, block):
    
    name_sb = str(stage) + str(block)
    
    # 1x1 conv
    conv1 = Conv2D(f1, (1,1), padding='same', activation='relu', name = 'conv_tower1_' + name_sb)(X)
    # 3x3 conv
    conv3 = Conv2D(f2_in, (1,1), padding='same', activation='relu', name = 'conv_tower2_1_' + name_sb)(X)
    conv3 = Conv2D(f2_out, (3,3), padding='same', activation='relu', name = 'conv_tower2_2' + name_sb)(conv3)
    # 5x5 conv
    conv5 = Conv2D(f3_in, (1,1), padding='same', activation='relu', name = 'conv_tower3_1_' + name_sb)(X)
    conv5 = Conv2D(f3_out, (5,5), padding='same', activation='relu', name = 'conv_tower3_2_' + name_sb)(conv5)
    # 3x3 max pooling
    pool = MaxPooling2D((3,3), strides=(1,1), padding='same', name = 'mpool_tower4_' + name_sb)(X)
    pool = Conv2D(f4_out, (1,1), padding='same', activation='relu', name = 'conv_tower4_' + name_sb)(pool)
    
    # concatenate filters
    layer_out = concatenate([conv1, conv3, conv5, pool], axis=-1)
    
    return layer_out

# %%
def auxiliary(x, classes, name=None):
    
    layer = AveragePooling2D(pool_size=(5,5), strides=3, padding='valid')(x)
    layer = Conv2D(filters=128, kernel_size=(1,1), strides=1, padding='same', activation='relu')(layer)
    layer = Flatten()(layer)
    layer = Dense(units=256, activation='relu')(layer)
    layer = Dropout(0.4)(layer)
    layer = Dense(units=classes, activation='softmax', name=name)(layer)
    
    return layer

# %%
def googlenet(input_shape, classes):
    
    X_input = Input(input_shape)

    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(32, (3, 3), strides = (2, 2), name = 'conv_pre_inception_1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_pre_inception_1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((2, 2), strides=(1, 1), name = 'mpool_pre_inception_1')(X)
    
    # Stage 2
    X = Conv2D(192, (3, 3), strides = (1, 1), name = 'conv_pre_inception_2', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_pre_inception_2')(X)
    X = Activation('relu')(X)
    X = Conv2D(192, (3, 3), strides = (1, 1), name = 'conv_pre_inception_3', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_pre_inception_3')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((2, 2), strides=(1, 1), name = 'mpool_pre_inception_2')(X)
    
    # Stage 3
    X = inception_module(X, 64, 96, 128, 16, 32, 32, 3, 'a')
    X = inception_module(X, 128, 128, 192, 32, 96, 64, 3, 'b')
    X = MaxPooling2D((2, 2), strides=(1, 1), name = 'mpool_inception_3')(X)
    
    # Stage 4
    X = inception_module(X, 192, 96, 208, 16, 48, 64, 4, 'a')
    aux1  = auxiliary(X, classes, name='aux1')
    X = inception_module(X, 160, 112, 224, 24, 64, 64, 4, 'b')
    X = inception_module(X, 128, 128, 256, 24, 24, 64, 4, 'c')
    X = inception_module(X, 112, 144, 288, 32, 64, 64, 4, 'd')
    aux2  = auxiliary(X, classes, name='aux2')
    X = inception_module(X, 256, 120, 320, 32, 128, 128, 4, 'e')
    X = MaxPooling2D((2, 2), strides=(1, 1), name = 'mpool_inception_4')(X)
    
    # Stage 5
    X = inception_module(X, 256, 160, 320, 32, 128, 128, 5, 'a')
    X = inception_module(X, 384, 192, 384, 48, 128, 128, 5, 'b')
    X = AveragePooling2D((7, 7), strides=(1, 1), name = 'apool_inception_5')(X)
    
    # Stage 6
    X = Dropout(0.4)(X)
    X = Flatten()(X)
    X = Dense(1000, activation='relu', kernel_initializer = glorot_uniform(seed=0))(X)
    main = Dense(classes, activation='softmax', name='main', kernel_initializer = glorot_uniform(seed=0))(X)
    
    aux1 = keras.layers.Lambda(lambda x: x * 0.3)(aux1)                                         
    aux2 = keras.layers.Lambda(lambda x: x * 0.3)(aux2)                                         
    totalloss = keras.layers.Add()([aux1, aux2, main])                     
    
    inceptionv1 = Model(inputs = X_input, outputs = [totalloss], name='InceptionV1')            
    opt = keras.optimizers.Adam(learning_rate=0.0001)
    inceptionv1.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return inceptionv1

# %% [markdown]
# ## With default dataset size (32,32,3)

# %% [markdown]
# ### CIFAR - 10

# %%
(c10_x_train_orig, c10_y_train_orig), (c10_x_test_orig, c10_y_test_orig) = cifar10.load_data()

# Pre-processing X
c10_x_train = c10_x_train_orig.astype('float32')
c10_x_test = c10_x_test_orig.astype('float32')
c10_x_train = c10_x_train/255
c10_x_test = c10_x_test/255

# Hyper-parameters
c10_epochs = 50
c10_batch_size = 128
c10_num_classes = 10
c10_input_shape = c10_x_train.shape[1:]

# Pre-processing Y
c10_y_train = keras.utils.to_categorical(c10_y_train_orig, c10_num_classes)
c10_y_test = keras.utils.to_categorical(c10_y_test_orig, c10_num_classes)

print(c10_x_train.shape, c10_x_test.shape, c10_y_train.shape, c10_y_test.shape)
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3) (50000, 10) (10000, 10)

# %%
c10_googlenet = googlenet(c10_input_shape, c10_num_classes)
c10_googlenet.summary()
# Out:
# Model: "InceptionV1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv_pre_inception_1 (Conv2D)   (None, 18, 18, 32)   896         zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_pre_inception_1 (BatchNormal (None, 18, 18, 32)   128         conv_pre_inception_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 18, 18, 32)   0           bn_pre_inception_1[0][0]
# __________________________________________________________________________________________________
# mpool_pre_inception_1 (MaxPooli (None, 17, 17, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv_pre_inception_2 (Conv2D)   (None, 15, 15, 192)  55488       mpool_pre_inception_1[0][0]
# __________________________________________________________________________________________________
# bn_pre_inception_2 (BatchNormal (None, 15, 15, 192)  768         conv_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 15, 15, 192)  0           bn_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_pre_inception_3 (Conv2D)   (None, 13, 13, 192)  331968      activation_2[0][0]
# __________________________________________________________________________________________________
# bn_pre_inception_3 (BatchNormal (None, 13, 13, 192)  768         conv_pre_inception_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 13, 13, 192)  0           bn_pre_inception_3[0][0]
# __________________________________________________________________________________________________
# mpool_pre_inception_2 (MaxPooli (None, 12, 12, 192)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_3a (Conv2D)       (None, 12, 12, 96)   18528       mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_3a (Conv2D)       (None, 12, 12, 16)   3088        mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_3a (MaxPooling2D)  (None, 12, 12, 192)  0           mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_tower1_3a (Conv2D)         (None, 12, 12, 64)   12352       mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_tower2_23a (Conv2D)        (None, 12, 12, 128)  110720      conv_tower2_1_3a[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_3a (Conv2D)       (None, 12, 12, 32)   12832       conv_tower3_1_3a[0][0]
# __________________________________________________________________________________________________
# conv_tower4_3a (Conv2D)         (None, 12, 12, 32)   6176        mpool_tower4_3a[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 256)  0           conv_tower1_3a[0][0]
#                                                                  conv_tower2_23a[0][0]
#                                                                  conv_tower3_2_3a[0][0]
#                                                                  conv_tower4_3a[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_3b (Conv2D)       (None, 12, 12, 128)  32896       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_3b (Conv2D)       (None, 12, 12, 32)   8224        concatenate_1[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_3b (MaxPooling2D)  (None, 12, 12, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv_tower1_3b (Conv2D)         (None, 12, 12, 128)  32896       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv_tower2_23b (Conv2D)        (None, 12, 12, 192)  221376      conv_tower2_1_3b[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_3b (Conv2D)       (None, 12, 12, 96)   76896       conv_tower3_1_3b[0][0]
# __________________________________________________________________________________________________
# conv_tower4_3b (Conv2D)         (None, 12, 12, 64)   16448       mpool_tower4_3b[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 12, 12, 480)  0           conv_tower1_3b[0][0]
#                                                                  conv_tower2_23b[0][0]
#                                                                  conv_tower3_2_3b[0][0]
#                                                                  conv_tower4_3b[0][0]
# __________________________________________________________________________________________________
# mpool_inception_3 (MaxPooling2D (None, 11, 11, 480)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4a (Conv2D)       (None, 11, 11, 96)   46176       mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4a (Conv2D)       (None, 11, 11, 16)   7696        mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4a (MaxPooling2D)  (None, 11, 11, 480)  0           mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4a (Conv2D)         (None, 11, 11, 192)  92352       mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24a (Conv2D)        (None, 11, 11, 208)  179920      conv_tower2_1_4a[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4a (Conv2D)       (None, 11, 11, 48)   19248       conv_tower3_1_4a[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4a (Conv2D)         (None, 11, 11, 64)   30784       mpool_tower4_4a[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 11, 11, 512)  0           conv_tower1_4a[0][0]
#                                                                  conv_tower2_24a[0][0]
#                                                                  conv_tower3_2_4a[0][0]
#                                                                  conv_tower4_4a[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4b (Conv2D)       (None, 11, 11, 112)  57456       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4b (Conv2D)       (None, 11, 11, 24)   12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4b (MaxPooling2D)  (None, 11, 11, 512)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4b (Conv2D)         (None, 11, 11, 160)  82080       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24b (Conv2D)        (None, 11, 11, 224)  226016      conv_tower2_1_4b[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4b (Conv2D)       (None, 11, 11, 64)   38464       conv_tower3_1_4b[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4b (Conv2D)         (None, 11, 11, 64)   32832       mpool_tower4_4b[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 11, 11, 512)  0           conv_tower1_4b[0][0]
#                                                                  conv_tower2_24b[0][0]
#                                                                  conv_tower3_2_4b[0][0]
#                                                                  conv_tower4_4b[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4c (Conv2D)       (None, 11, 11, 128)  65664       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4c (Conv2D)       (None, 11, 11, 24)   12312       concatenate_4[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4c (MaxPooling2D)  (None, 11, 11, 512)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4c (Conv2D)         (None, 11, 11, 128)  65664       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24c (Conv2D)        (None, 11, 11, 256)  295168      conv_tower2_1_4c[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4c (Conv2D)       (None, 11, 11, 24)   14424       conv_tower3_1_4c[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4c (Conv2D)         (None, 11, 11, 64)   32832       mpool_tower4_4c[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 11, 11, 472)  0           conv_tower1_4c[0][0]
#                                                                  conv_tower2_24c[0][0]
#                                                                  conv_tower3_2_4c[0][0]
#                                                                  conv_tower4_4c[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4d (Conv2D)       (None, 11, 11, 144)  68112       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4d (Conv2D)       (None, 11, 11, 32)   15136       concatenate_5[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4d (MaxPooling2D)  (None, 11, 11, 472)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4d (Conv2D)         (None, 11, 11, 112)  52976       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24d (Conv2D)        (None, 11, 11, 288)  373536      conv_tower2_1_4d[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4d (Conv2D)       (None, 11, 11, 64)   51264       conv_tower3_1_4d[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4d (Conv2D)         (None, 11, 11, 64)   30272       mpool_tower4_4d[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 11, 11, 528)  0           conv_tower1_4d[0][0]
#                                                                  conv_tower2_24d[0][0]
#                                                                  conv_tower3_2_4d[0][0]
#                                                                  conv_tower4_4d[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4e (Conv2D)       (None, 11, 11, 120)  63480       concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4e (Conv2D)       (None, 11, 11, 32)   16928       concatenate_6[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4e (MaxPooling2D)  (None, 11, 11, 528)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4e (Conv2D)         (None, 11, 11, 256)  135424      concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24e (Conv2D)        (None, 11, 11, 320)  345920      conv_tower2_1_4e[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4e (Conv2D)       (None, 11, 11, 128)  102528      conv_tower3_1_4e[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4e (Conv2D)         (None, 11, 11, 128)  67712       mpool_tower4_4e[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 11, 11, 832)  0           conv_tower1_4e[0][0]
#                                                                  conv_tower2_24e[0][0]
#                                                                  conv_tower3_2_4e[0][0]
#                                                                  conv_tower4_4e[0][0]
# __________________________________________________________________________________________________
# mpool_inception_4 (MaxPooling2D (None, 10, 10, 832)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_5a (Conv2D)       (None, 10, 10, 160)  133280      mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_5a (Conv2D)       (None, 10, 10, 32)   26656       mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_5a (MaxPooling2D)  (None, 10, 10, 832)  0           mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# conv_tower1_5a (Conv2D)         (None, 10, 10, 256)  213248      mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# conv_tower2_25a (Conv2D)        (None, 10, 10, 320)  461120      conv_tower2_1_5a[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_5a (Conv2D)       (None, 10, 10, 128)  102528      conv_tower3_1_5a[0][0]
# __________________________________________________________________________________________________
# conv_tower4_5a (Conv2D)         (None, 10, 10, 128)  106624      mpool_tower4_5a[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 10, 10, 832)  0           conv_tower1_5a[0][0]
#                                                                  conv_tower2_25a[0][0]
#                                                                  conv_tower3_2_5a[0][0]
#                                                                  conv_tower4_5a[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_5b (Conv2D)       (None, 10, 10, 192)  159936      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_5b (Conv2D)       (None, 10, 10, 48)   39984       concatenate_8[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_5b (MaxPooling2D)  (None, 10, 10, 832)  0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 3, 3, 512)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 3, 3, 528)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower1_5b (Conv2D)         (None, 10, 10, 384)  319872      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv_tower2_25b (Conv2D)        (None, 10, 10, 384)  663936      conv_tower2_1_5b[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_5b (Conv2D)       (None, 10, 10, 128)  153728      conv_tower3_1_5b[0][0]
# __________________________________________________________________________________________________
# conv_tower4_5b (Conv2D)         (None, 10, 10, 128)  106624      mpool_tower4_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 3, 3, 128)    65664       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 3, 3, 128)    67712       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 10, 10, 1024) 0           conv_tower1_5b[0][0]
#                                                                  conv_tower2_25b[0][0]
#                                                                  conv_tower3_2_5b[0][0]
#                                                                  conv_tower4_5b[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1152)         0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1152)         0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# apool_inception_5 (AveragePooli (None, 4, 4, 1024)   0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          295168      flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          295168      flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 1024)   0           apool_inception_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 16384)        0           dropout_3[0][0]
# __________________________________________________________________________________________________
# aux1 (Dense)                    (None, 10)           2570        dropout_1[0][0]
# __________________________________________________________________________________________________
# aux2 (Dense)                    (None, 10)           2570        dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1000)         16385000    flatten_3[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 10)           0           aux1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 10)           0           aux2[0][0]
# __________________________________________________________________________________________________
# main (Dense)                    (None, 10)           10010       dense_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 10)           0           lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  main[0][0]
# ==================================================================================================
# Total params: 23,188,534
# Trainable params: 23,187,702
# Non-trainable params: 832
# __________________________________________________________________________________________________

# %%
c10_googlenet.fit(c10_x_train, c10_y_train, validation_data = (c10_x_test, c10_y_test), epochs = c10_epochs, batch_size = c10_batch_size)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 1.5644 - accuracy: 0.4086 - val_loss: 2.1582 - val_accuracy: 0.2336
# Epoch 2/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.1712 - accuracy: 0.5754 - val_loss: 1.1011 - val_accuracy: 0.6033
# Epoch 3/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.9966 - accuracy: 0.6452 - val_loss: 1.0458 - val_accuracy: 0.6180
# Epoch 4/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.8869 - accuracy: 0.6860 - val_loss: 0.9362 - val_accuracy: 0.6564
# Epoch 5/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.7800 - accuracy: 0.7270 - val_loss: 0.8768 - val_accuracy: 0.6913
# Epoch 6/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.6936 - accuracy: 0.7601 - val_loss: 0.8487 - val_accuracy: 0.7031
# Epoch 7/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.6241 - accuracy: 0.7843 - val_loss: 0.7965 - val_accuracy: 0.7338
# Epoch 8/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.5618 - accuracy: 0.8062 - val_loss: 0.8457 - val_accuracy: 0.7143
# Epoch 9/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.5042 - accuracy: 0.8257 - val_loss: 0.7811 - val_accuracy: 0.7363
# Epoch 10/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.4497 - accuracy: 0.8473 - val_loss: 0.8169 - val_accuracy: 0.7272
# Epoch 11/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.4082 - accuracy: 0.8628 - val_loss: 0.8439 - val_accuracy: 0.7333
# Epoch 12/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.3599 - accuracy: 0.8803 - val_loss: 0.8650 - val_accuracy: 0.7416
# Epoch 13/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.3222 - accuracy: 0.8930 - val_loss: 0.8626 - val_accuracy: 0.7370
# Epoch 14/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.2877 - accuracy: 0.9064 - val_loss: 0.8620 - val_accuracy: 0.7363
# Epoch 15/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.2541 - accuracy: 0.9189 - val_loss: 0.8315 - val_accuracy: 0.7480
# Epoch 16/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.2347 - accuracy: 0.9236 - val_loss: 1.0188 - val_accuracy: 0.7442
# Epoch 17/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.2008 - accuracy: 0.9381 - val_loss: 0.8792 - val_accuracy: 0.7571
# Epoch 18/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.1908 - accuracy: 0.9400 - val_loss: 0.9635 - val_accuracy: 0.7443
# Epoch 19/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.1655 - accuracy: 0.9490 - val_loss: 0.9724 - val_accuracy: 0.7536accuracy:  - ETA: 7s - - ETA:  - ETA: 0s - loss: 0.1652 - accura
# Epoch 20/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.1541 - accuracy: 0.9524 - val_loss: 1.0587 - val_accuracy: 0.7288ETA: 33s - loss: 0.1504 - a - ETA: 30s - loss: 0.1523 - ac - ETA: 27s - loss: 0.1536 - accuracy: 0.952 - ET - ETA: 19s -  - ETA: 2s - loss: 0.1 - ETA: 0s - loss: 0.1540 - accuracy:
# Epoch 21/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.1492 - accuracy: 0.9547 - val_loss: 0.9819 - val_accuracy: 0.7638
# Epoch 22/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.1329 - accuracy: 0.9602 - val_loss: 1.0791 - val_accuracy: 0.7367
# Epoch 23/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.1256 - accuracy: 0.9613 - val_loss: 1.0857 - val_accuracy: 0.7407
# Epoch 24/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.1273 - accuracy: 0.9612 - val_loss: 1.1380 - val_accuracy: 0.7255
# Epoch 25/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0997 - accuracy: 0.9720 - val_loss: 1.0199 - val_accuracy: 0.7592.0907 - ac - ETA: 31s - loss
# Epoch 26/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.1103 - accuracy: 0.9668 - val_loss: 1.0495 - val_accuracy: 0.7584
# Epoch 27/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0978 - accuracy: 0.9708 - val_loss: 1.1173 - val_accuracy: 0.7425
# Epoch 28/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0988 - accuracy: 0.9700 - val_loss: 1.1134 - val_accuracy: 0.7483
# Epoch 29/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0956 - accuracy: 0.9711 - val_loss: 1.1426 - val_accuracy: 0.75240.09 - ETA: 1s - loss: 0.0941 - accura - ETA: 0s - loss: 0.0952 - accuracy
# Epoch 30/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0846 - accuracy: 0.9750 - val_loss: 1.1513 - val_accuracy: 0.7471ss: 0.0798 - accuracy: 0.976 - ETA: 11s - ETA: 7s - loss: 0.0823 - ac - ETA: 1s - loss: 0.0845 -
# Epoch 31/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0879 - accuracy: 0.9733 - val_loss: 1.0665 - val_accuracy: 0.7594
# Epoch 32/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0882 - accuracy: 0.9736 - val_loss: 1.2812 - val_accuracy: 0.7458
# Epoch 33/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0685 - accuracy: 0.9805 - val_loss: 1.0928 - val_accuracy: 0.7649- los
# Epoch 34/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0656 - accuracy: 0.9814 - val_loss: 1.1524 - val_accuracy: 0.7530
# Epoch 35/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0885 - accuracy: 0.9716 - val_loss: 1.0585 - val_accuracy: 0.7774
# Epoch 36/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0667 - accuracy: 0.9805 - val_loss: 1.1101 - val_accuracy: 0.7645
# Epoch 37/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0654 - accuracy: 0.9810 - val_loss: 1.2053 - val_accuracy: 0.7482
# Epoch 38/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0722 - accuracy: 0.9780 - val_loss: 1.1262 - val_accuracy: 0.7667s -
# Epoch 39/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0663 - accuracy: 0.9806 - val_loss: 1.2019 - val_accuracy: 0.7498A: 9s - loss: 0.0660 - ETA:
# Epoch 40/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0449 - accuracy: 0.9882 - val_loss: 1.2024 - val_accuracy: 0.7757 3s -
# Epoch 41/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0627 - accuracy: 0.9810 - val_loss: 1.2611 - val_accuracy: 0.7604
# Epoch 42/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0779 - accuracy: 0.9753 - val_loss: 1.0952 - val_accuracy: 0.7652
# Epoch 43/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0493 - accuracy: 0.9867 - val_loss: 1.3643 - val_accuracy: 0.7530
# Epoch 44/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0525 - accuracy: 0.9844 - val_loss: 1.1073 - val_accuracy: 0.7731
# Epoch 45/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0478 - accuracy: 0.9865 - val_loss: 1.4971 - val_accuracy: 0.7253
# Epoch 46/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0643 - accuracy: 0.9797 - val_loss: 1.1396 - val_accuracy: 0.7707
# Epoch 47/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0550 - accuracy: 0.9837 - val_loss: 1.0974 - val_accuracy: 0.7784
# Epoch 48/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0453 - accuracy: 0.9867 - val_loss: 1.3478 - val_accuracy: 0.7518
# Epoch 49/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0555 - accuracy: 0.9823 - val_loss: 1.2208 - val_accuracy: 0.7522
# Epoch 50/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.0473 - accuracy: 0.9867 - val_loss: 1.2876 - val_accuracy: 0.7613

# %%
scores = c10_googlenet.evaluate(c10_x_test, c10_y_test)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 7s 666us/step
# Test loss: 1.2876167963027954
# Test accuracy: 0.7613000273704529

# %%
predictions = {}
for i in range(c10_num_classes):
    index = np.where(c10_y_test_orig == i)
    slice_x_test = c10_x_test[index[0]]
    slice_y_test = c10_y_test[index[0]]
    scores = c10_googlenet.evaluate(slice_x_test, slice_y_test, verbose = 0)
    print('Class: ' + c10_class_name[i] + ' Test accuracy: ' + str(scores[1]))
    predictions[c10_class_name[i]] = str(scores[1])
# Out:
# Class: airplane Test accuracy: 0.7089999914169312
# Class: automobile Test accuracy: 0.8939999938011169
# Class: bird Test accuracy: 0.6690000295639038
# Class: cat Test accuracy: 0.5450000166893005
# Class: deer Test accuracy: 0.7229999899864197
# Class: dog Test accuracy: 0.8339999914169312
# Class: frog Test accuracy: 0.7699999809265137
# Class: horse Test accuracy: 0.7310000061988831
# Class: ship Test accuracy: 0.8330000042915344
# Class: truck Test accuracy: 0.9049999713897705

# %% [markdown]
# ### CIFAR - 100

# %%
# Load data
(c100_x_train_orig, c100_y_train_orig), (c100_x_test_orig, c100_y_test_orig) = cifar100.load_data()

# Pre-processing X
c100_x_train = c100_x_train_orig.astype('float32')
c100_x_test = c100_x_test_orig.astype('float32')
c100_x_train = c100_x_train/255
c100_x_test = c100_x_test/255

# Hyper-parameters
c100_epochs = 50
c100_batch_size = 128
c100_num_classes = 100
c100_input_shape = c100_x_train.shape[1:]

# Pre-processing Y
c100_y_train = keras.utils.to_categorical(c100_y_train_orig, c100_num_classes)
c100_y_test = keras.utils.to_categorical(c100_y_test_orig, c100_num_classes)

print(c100_x_train.shape, c100_x_test.shape, c100_y_train.shape, c100_y_test.shape)
# Out:
# (50000, 32, 32, 3) (10000, 32, 32, 3) (50000, 100) (10000, 100)

# %%
c100_googlenet = googlenet(c100_input_shape, c100_num_classes)
c100_googlenet.summary()
# Out:
# Model: "InceptionV1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 38, 38, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv_pre_inception_1 (Conv2D)   (None, 18, 18, 32)   896         zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn_pre_inception_1 (BatchNormal (None, 18, 18, 32)   128         conv_pre_inception_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 18, 18, 32)   0           bn_pre_inception_1[0][0]
# __________________________________________________________________________________________________
# mpool_pre_inception_1 (MaxPooli (None, 17, 17, 32)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv_pre_inception_2 (Conv2D)   (None, 15, 15, 192)  55488       mpool_pre_inception_1[0][0]
# __________________________________________________________________________________________________
# bn_pre_inception_2 (BatchNormal (None, 15, 15, 192)  768         conv_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 15, 15, 192)  0           bn_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_pre_inception_3 (Conv2D)   (None, 13, 13, 192)  331968      activation_2[0][0]
# __________________________________________________________________________________________________
# bn_pre_inception_3 (BatchNormal (None, 13, 13, 192)  768         conv_pre_inception_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 13, 13, 192)  0           bn_pre_inception_3[0][0]
# __________________________________________________________________________________________________
# mpool_pre_inception_2 (MaxPooli (None, 12, 12, 192)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_3a (Conv2D)       (None, 12, 12, 96)   18528       mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_3a (Conv2D)       (None, 12, 12, 16)   3088        mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_3a (MaxPooling2D)  (None, 12, 12, 192)  0           mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_tower1_3a (Conv2D)         (None, 12, 12, 64)   12352       mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_tower2_23a (Conv2D)        (None, 12, 12, 128)  110720      conv_tower2_1_3a[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_3a (Conv2D)       (None, 12, 12, 32)   12832       conv_tower3_1_3a[0][0]
# __________________________________________________________________________________________________
# conv_tower4_3a (Conv2D)         (None, 12, 12, 32)   6176        mpool_tower4_3a[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 256)  0           conv_tower1_3a[0][0]
#                                                                  conv_tower2_23a[0][0]
#                                                                  conv_tower3_2_3a[0][0]
#                                                                  conv_tower4_3a[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_3b (Conv2D)       (None, 12, 12, 128)  32896       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_3b (Conv2D)       (None, 12, 12, 32)   8224        concatenate_1[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_3b (MaxPooling2D)  (None, 12, 12, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv_tower1_3b (Conv2D)         (None, 12, 12, 128)  32896       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv_tower2_23b (Conv2D)        (None, 12, 12, 192)  221376      conv_tower2_1_3b[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_3b (Conv2D)       (None, 12, 12, 96)   76896       conv_tower3_1_3b[0][0]
# __________________________________________________________________________________________________
# conv_tower4_3b (Conv2D)         (None, 12, 12, 64)   16448       mpool_tower4_3b[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 12, 12, 480)  0           conv_tower1_3b[0][0]
#                                                                  conv_tower2_23b[0][0]
#                                                                  conv_tower3_2_3b[0][0]
#                                                                  conv_tower4_3b[0][0]
# __________________________________________________________________________________________________
# mpool_inception_3 (MaxPooling2D (None, 11, 11, 480)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4a (Conv2D)       (None, 11, 11, 96)   46176       mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4a (Conv2D)       (None, 11, 11, 16)   7696        mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4a (MaxPooling2D)  (None, 11, 11, 480)  0           mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4a (Conv2D)         (None, 11, 11, 192)  92352       mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24a (Conv2D)        (None, 11, 11, 208)  179920      conv_tower2_1_4a[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4a (Conv2D)       (None, 11, 11, 48)   19248       conv_tower3_1_4a[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4a (Conv2D)         (None, 11, 11, 64)   30784       mpool_tower4_4a[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 11, 11, 512)  0           conv_tower1_4a[0][0]
#                                                                  conv_tower2_24a[0][0]
#                                                                  conv_tower3_2_4a[0][0]
#                                                                  conv_tower4_4a[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4b (Conv2D)       (None, 11, 11, 112)  57456       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4b (Conv2D)       (None, 11, 11, 24)   12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4b (MaxPooling2D)  (None, 11, 11, 512)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4b (Conv2D)         (None, 11, 11, 160)  82080       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24b (Conv2D)        (None, 11, 11, 224)  226016      conv_tower2_1_4b[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4b (Conv2D)       (None, 11, 11, 64)   38464       conv_tower3_1_4b[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4b (Conv2D)         (None, 11, 11, 64)   32832       mpool_tower4_4b[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 11, 11, 512)  0           conv_tower1_4b[0][0]
#                                                                  conv_tower2_24b[0][0]
#                                                                  conv_tower3_2_4b[0][0]
#                                                                  conv_tower4_4b[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4c (Conv2D)       (None, 11, 11, 128)  65664       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4c (Conv2D)       (None, 11, 11, 24)   12312       concatenate_4[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4c (MaxPooling2D)  (None, 11, 11, 512)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4c (Conv2D)         (None, 11, 11, 128)  65664       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24c (Conv2D)        (None, 11, 11, 256)  295168      conv_tower2_1_4c[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4c (Conv2D)       (None, 11, 11, 24)   14424       conv_tower3_1_4c[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4c (Conv2D)         (None, 11, 11, 64)   32832       mpool_tower4_4c[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 11, 11, 472)  0           conv_tower1_4c[0][0]
#                                                                  conv_tower2_24c[0][0]
#                                                                  conv_tower3_2_4c[0][0]
#                                                                  conv_tower4_4c[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4d (Conv2D)       (None, 11, 11, 144)  68112       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4d (Conv2D)       (None, 11, 11, 32)   15136       concatenate_5[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4d (MaxPooling2D)  (None, 11, 11, 472)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4d (Conv2D)         (None, 11, 11, 112)  52976       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24d (Conv2D)        (None, 11, 11, 288)  373536      conv_tower2_1_4d[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4d (Conv2D)       (None, 11, 11, 64)   51264       conv_tower3_1_4d[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4d (Conv2D)         (None, 11, 11, 64)   30272       mpool_tower4_4d[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 11, 11, 528)  0           conv_tower1_4d[0][0]
#                                                                  conv_tower2_24d[0][0]
#                                                                  conv_tower3_2_4d[0][0]
#                                                                  conv_tower4_4d[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4e (Conv2D)       (None, 11, 11, 120)  63480       concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4e (Conv2D)       (None, 11, 11, 32)   16928       concatenate_6[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4e (MaxPooling2D)  (None, 11, 11, 528)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4e (Conv2D)         (None, 11, 11, 256)  135424      concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24e (Conv2D)        (None, 11, 11, 320)  345920      conv_tower2_1_4e[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4e (Conv2D)       (None, 11, 11, 128)  102528      conv_tower3_1_4e[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4e (Conv2D)         (None, 11, 11, 128)  67712       mpool_tower4_4e[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 11, 11, 832)  0           conv_tower1_4e[0][0]
#                                                                  conv_tower2_24e[0][0]
#                                                                  conv_tower3_2_4e[0][0]
#                                                                  conv_tower4_4e[0][0]
# __________________________________________________________________________________________________
# mpool_inception_4 (MaxPooling2D (None, 10, 10, 832)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_5a (Conv2D)       (None, 10, 10, 160)  133280      mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_5a (Conv2D)       (None, 10, 10, 32)   26656       mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_5a (MaxPooling2D)  (None, 10, 10, 832)  0           mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# conv_tower1_5a (Conv2D)         (None, 10, 10, 256)  213248      mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# conv_tower2_25a (Conv2D)        (None, 10, 10, 320)  461120      conv_tower2_1_5a[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_5a (Conv2D)       (None, 10, 10, 128)  102528      conv_tower3_1_5a[0][0]
# __________________________________________________________________________________________________
# conv_tower4_5a (Conv2D)         (None, 10, 10, 128)  106624      mpool_tower4_5a[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 10, 10, 832)  0           conv_tower1_5a[0][0]
#                                                                  conv_tower2_25a[0][0]
#                                                                  conv_tower3_2_5a[0][0]
#                                                                  conv_tower4_5a[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_5b (Conv2D)       (None, 10, 10, 192)  159936      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_5b (Conv2D)       (None, 10, 10, 48)   39984       concatenate_8[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_5b (MaxPooling2D)  (None, 10, 10, 832)  0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 3, 3, 512)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 3, 3, 528)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower1_5b (Conv2D)         (None, 10, 10, 384)  319872      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv_tower2_25b (Conv2D)        (None, 10, 10, 384)  663936      conv_tower2_1_5b[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_5b (Conv2D)       (None, 10, 10, 128)  153728      conv_tower3_1_5b[0][0]
# __________________________________________________________________________________________________
# conv_tower4_5b (Conv2D)         (None, 10, 10, 128)  106624      mpool_tower4_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 3, 3, 128)    65664       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 3, 3, 128)    67712       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 10, 10, 1024) 0           conv_tower1_5b[0][0]
#                                                                  conv_tower2_25b[0][0]
#                                                                  conv_tower3_2_5b[0][0]
#                                                                  conv_tower4_5b[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 1152)         0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1152)         0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# apool_inception_5 (AveragePooli (None, 4, 4, 1024)   0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 256)          295168      flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 256)          295168      flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 1024)   0           apool_inception_5[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 256)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 16384)        0           dropout_3[0][0]
# __________________________________________________________________________________________________
# aux1 (Dense)                    (None, 100)          25700       dropout_1[0][0]
# __________________________________________________________________________________________________
# aux2 (Dense)                    (None, 100)          25700       dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1000)         16385000    flatten_3[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 100)          0           aux1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 100)          0           aux2[0][0]
# __________________________________________________________________________________________________
# main (Dense)                    (None, 100)          100100      dense_3[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 100)          0           lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  main[0][0]
# ==================================================================================================
# Total params: 23,324,884
# Trainable params: 23,324,052
# Non-trainable params: 832
# __________________________________________________________________________________________________

# %%
c100_googlenet.fit(c100_x_train, c100_y_train, validation_data = (c100_x_test, c100_y_test), epochs = c100_epochs, batch_size = c100_batch_size)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 94s 2ms/step - loss: 3.9716 - accuracy: 0.0883 - val_loss: 4.7106 - val_accuracy: 0.0271
# Epoch 2/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 3.3793 - accuracy: 0.1817 - val_loss: 3.2536 - val_accuracy: 0.20293811 - accura
# Epoch 3/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 3.0526 - accuracy: 0.2395 - val_loss: 3.0299 - val_accuracy: 0.2425
# Epoch 4/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 2.7880 - accuracy: 0.2940 - val_loss: 2.8335 - val_accuracy: 0.2820
# Epoch 5/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 2.5646 - accuracy: 0.3425 - val_loss: 2.5946 - val_accuracy: 0.3344ccu
# Epoch 6/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 2.3901 - accuracy: 0.3815 - val_loss: 2.5111 - val_accuracy: 0.3537
# Epoch 7/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 2.2342 - accuracy: 0.4143 - val_loss: 2.3623 - val_accuracy: 0.3895
# Epoch 8/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 2.1038 - accuracy: 0.4494 - val_loss: 2.4935 - val_accuracy: 0.3554
# Epoch 9/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.9806 - accuracy: 0.4808 - val_loss: 2.2858 - val_accuracy: 0.4009
# Epoch 10/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.8705 - accuracy: 0.5048 - val_loss: 2.3460 - val_accuracy: 0.3887
# Epoch 11/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.7601 - accuracy: 0.5341 - val_loss: 2.1849 - val_accuracy: 0.4301
# Epoch 12/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.6517 - accuracy: 0.5639 - val_loss: 2.1676 - val_accuracy: 0.4399
# Epoch 13/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.5616 - accuracy: 0.5859 - val_loss: 2.2757 - val_accuracy: 0.4267
# Epoch 14/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.4671 - accuracy: 0.6122 - val_loss: 2.2942 - val_accuracy: 0.4299
# Epoch 15/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.3795 - accuracy: 0.6370 - val_loss: 2.1257 - val_accuracy: 0.4585
# Epoch 16/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.2975 - accuracy: 0.6607 - val_loss: 2.1947 - val_accuracy: 0.4463
# Epoch 17/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.2195 - accuracy: 0.6820 - val_loss: 2.2587 - val_accuracy: 0.4346
# Epoch 18/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.1560 - accuracy: 0.7002 - val_loss: 2.1678 - val_accuracy: 0.4546
# Epoch 19/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.0755 - accuracy: 0.7243 - val_loss: 2.3429 - val_accuracy: 0.4345
# Epoch 20/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 1.0202 - accuracy: 0.7413 - val_loss: 2.2916 - val_accuracy: 0.4526
# Epoch 21/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.9682 - accuracy: 0.7552 - val_loss: 2.2410 - val_accuracy: 0.4594
# Epoch 22/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.9143 - accuracy: 0.7724 - val_loss: 2.3734 - val_accuracy: 0.4456
# Epoch 23/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.8679 - accuracy: 0.7849 - val_loss: 2.3240 - val_accuracy: 0.4606
# Epoch 24/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.8326 - accuracy: 0.7964 - val_loss: 2.3527 - val_accuracy: 0.4588
# Epoch 25/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.7968 - accuracy: 0.8070 - val_loss: 2.3419 - val_accuracy: 0.4592
# Epoch 26/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.7607 - accuracy: 0.8190 - val_loss: 2.4913 - val_accuracy: 0.4392
# Epoch 27/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.7521 - accuracy: 0.8204 - val_loss: 2.3757 - val_accuracy: 0.4642
# Epoch 28/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.7072 - accuracy: 0.8366 - val_loss: 2.4632 - val_accuracy: 0.4600A: 44s -  - ETA: 29s - loss: 0.6896 - a
# Epoch 29/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.6935 - accuracy: 0.8385 - val_loss: 2.4500 - val_accuracy: 0.4605loss: 0.6862 - accura
# Epoch 30/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.6650 - accuracy: 0.8493 - val_loss: 2.5027 - val_accuracy: 0.4666
# Epoch 31/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.6488 - accuracy: 0.8534 - val_loss: 2.5871 - val_accuracy: 0.4532
# Epoch 32/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.6518 - accuracy: 0.8513 - val_loss: 2.4314 - val_accuracy: 0.4690
# Epoch 33/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.6212 - accuracy: 0.8607 - val_loss: 2.5131 - val_accuracy: 0.4605
# Epoch 34/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.6059 - accuracy: 0.8663 - val_loss: 2.4985 - val_accuracy: 0.4719
# Epoch 35/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.5982 - accuracy: 0.8673 - val_loss: 2.6756 - val_accuracy: 0.4470
# Epoch 36/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.5875 - accuracy: 0.8706 - val_loss: 2.6567 - val_accuracy: 0.4539
# Epoch 37/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.5666 - accuracy: 0.8769 - val_loss: 2.7115 - val_accuracy: 0.4500
# Epoch 38/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.5726 - accuracy: 0.8739 - val_loss: 2.5965 - val_accuracy: 0.4727
# Epoch 39/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.5623 - accuracy: 0.8775 - val_loss: 2.5547 - val_accuracy: 0.4727
# Epoch 40/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.5522 - accuracy: 0.8807 - val_loss: 2.6468 - val_accuracy: 0.4641
# Epoch 41/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.5314 - accuracy: 0.8882 - val_loss: 2.6468 - val_accuracy: 0.4642
# Epoch 42/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.5337 - accuracy: 0.8869 - val_loss: 2.6058 - val_accuracy: 0.4633
# Epoch 43/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.5211 - accuracy: 0.8902 - val_loss: 2.5818 - val_accuracy: 0.4826
# Epoch 44/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.5097 - accuracy: 0.8948 - val_loss: 2.5864 - val_accuracy: 0.4718
# Epoch 45/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.5032 - accuracy: 0.8949 - val_loss: 2.6908 - val_accuracy: 0.4750
# Epoch 46/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.5060 - accuracy: 0.8945 - val_loss: 2.6691 - val_accuracy: 0.4663
# Epoch 47/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.4981 - accuracy: 0.8954 - val_loss: 2.6933 - val_accuracy: 0.4556
# Epoch 48/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.4883 - accuracy: 0.8989 - val_loss: 2.6563 - val_accuracy: 0.4743
# Epoch 49/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.4771 - accuracy: 0.9040 - val_loss: 2.6264 - val_accuracy: 0.4842- ETA: 2s - los
# Epoch 50/50
# 50000/50000 [==============================] - 83s 2ms/step - loss: 0.4737 - accuracy: 0.9032 - val_loss: 2.7607 - val_accuracy: 0.4802

# %%
scores = c100_googlenet.evaluate(c100_x_test, c100_y_test)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 7s 661us/step
# Test loss: 2.7607055408477783
# Test accuracy: 0.48019999265670776

# %%
predictions = {}
for i in range(c100_num_classes):
    index = np.where(c100_y_test_orig == i)
    slice_x_test = c100_x_test[index[0]]
    slice_y_test = c100_y_test[index[0]]
    scores = c100_googlenet.evaluate(slice_x_test, slice_y_test, verbose = 0)
    print('Class: ' + c100_class_name[i] + ' Test accuracy: ' + str(scores[1]))
    predictions[c100_class_name[i]] = str(scores[1])
# Out:
# Class: apple Test accuracy: 0.7200000286102295
# Class: aquarium_fish Test accuracy: 0.6899999976158142
# Class: baby Test accuracy: 0.4300000071525574
# Class: bear Test accuracy: 0.25
# Class: beaver Test accuracy: 0.30000001192092896
# Class: bed Test accuracy: 0.36000001430511475
# Class: bee Test accuracy: 0.5699999928474426
# Class: beetle Test accuracy: 0.4300000071525574
# Class: bicycle Test accuracy: 0.6899999976158142
# Class: bottle Test accuracy: 0.6200000047683716
# Class: bowl Test accuracy: 0.20999999344348907
# Class: boy Test accuracy: 0.3499999940395355
# Class: bridge Test accuracy: 0.47999998927116394
# Class: bus Test accuracy: 0.49000000953674316
# Class: butterfly Test accuracy: 0.38999998569488525
# Class: camel Test accuracy: 0.5099999904632568
# Class: can Test accuracy: 0.5
# Class: castle Test accuracy: 0.7200000286102295
# Class: caterpillar Test accuracy: 0.38999998569488525
# Class: cattle Test accuracy: 0.4000000059604645
# Class: chair Test accuracy: 0.05000000074505806
# Class: chimpanzee Test accuracy: 0.6800000071525574
# Class: clock Test accuracy: 0.4399999976158142
# Class: cloud Test accuracy: 0.5600000023841858
# Class: cockroach Test accuracy: 0.699999988079071
# Class: couch Test accuracy: 0.5
# Class: crab Test accuracy: 0.5099999904632568
# Class: crocodile Test accuracy: 0.27000001072883606
# Class: cup Test accuracy: 0.5199999809265137
# Class: dinosaur Test accuracy: 0.5099999904632568
# Class: dolphin Test accuracy: 0.3799999952316284
# Class: elephant Test accuracy: 0.28999999165534973
# Class: flatfish Test accuracy: 0.41999998688697815
# Class: forest Test accuracy: 0.5199999809265137
# Class: fox Test accuracy: 0.3199999928474426
# Class: girl Test accuracy: 0.2800000011920929
# Class: hamster Test accuracy: 0.550000011920929
# Class: house Test accuracy: 0.49000000953674316
# Class: kangaroo Test accuracy: 0.23999999463558197
# Class: keyboard Test accuracy: 0.6399999856948853
# Class: lamp Test accuracy: 0.4099999964237213
# Class: lawn_mower Test accuracy: 0.5899999737739563
# Class: leopard Test accuracy: 0.33000001311302185
# Class: lion Test accuracy: 0.5
# Class: lizard Test accuracy: 0.25999999046325684
# Class: lobster Test accuracy: 0.23999999463558197
# Class: man Test accuracy: 0.18000000715255737
# Class: maple_tree Test accuracy: 0.49000000953674316
# Class: motorcycle Test accuracy: 0.7699999809265137
# Class: mountain Test accuracy: 0.699999988079071
# Class: mouse Test accuracy: 0.25999999046325684
# Class: mushroom Test accuracy: 0.36000001430511475
# Class: oak_tree Test accuracy: 0.6299999952316284
# Class: orange Test accuracy: 0.800000011920929
# Class: orchid Test accuracy: 0.5400000214576721
# Class: otter Test accuracy: 0.10000000149011612
# Class: palm_tree Test accuracy: 0.75
# Class: pear Test accuracy: 0.5199999809265137
# Class: pickup_truck Test accuracy: 0.5899999737739563
# Class: pine_tree Test accuracy: 0.41999998688697815
# Class: plain Test accuracy: 0.7599999904632568
# Class: plate Test accuracy: 0.6200000047683716
# Class: poppy Test accuracy: 0.550000011920929
# Class: porcupine Test accuracy: 0.4099999964237213
# Class: possum Test accuracy: 0.28999999165534973
# Class: rabbit Test accuracy: 0.3400000035762787
# Class: raccoon Test accuracy: 0.550000011920929
# Class: ray Test accuracy: 0.28999999165534973
# Class: road Test accuracy: 0.8100000023841858
# Class: rocket Test accuracy: 0.6100000143051147
# Class: rose Test accuracy: 0.5799999833106995
# Class: sea Test accuracy: 0.5799999833106995
# Class: seal Test accuracy: 0.20000000298023224
# Class: shark Test accuracy: 0.3400000035762787
# Class: shrew Test accuracy: 0.30000001192092896
# Class: skunk Test accuracy: 0.75
# Class: skyscraper Test accuracy: 0.7599999904632568
# Class: snail Test accuracy: 0.3799999952316284
# Class: snake Test accuracy: 0.3700000047683716
# Class: spider Test accuracy: 0.47999998927116394
# Class: squirrel Test accuracy: 0.33000001311302185
# Class: streetcar Test accuracy: 0.5600000023841858
# Class: sunflower Test accuracy: 0.8299999833106995
# Class: sweet_pepper Test accuracy: 0.5
# Class: table Test accuracy: 0.3499999940395355
# Class: tank Test accuracy: 0.699999988079071
# Class: telephone Test accuracy: 0.6100000143051147
# Class: television Test accuracy: 0.46000000834465027
# Class: tiger Test accuracy: 0.5199999809265137
# Class: tractor Test accuracy: 0.6499999761581421
# Class: train Test accuracy: 0.46000000834465027
# Class: trout Test accuracy: 0.6299999952316284
# Class: tulip Test accuracy: 0.30000001192092896
# Class: turtle Test accuracy: 0.3700000047683716
# Class: wardrobe Test accuracy: 0.7900000214576721
# Class: whale Test accuracy: 0.4000000059604645
# Class: willow_tree Test accuracy: 0.5199999809265137
# Class: wolf Test accuracy: 0.5400000214576721
# Class: woman Test accuracy: 0.1899999976158142
# Class: worm Test accuracy: 0.5299999713897705

# %% [markdown]
# ## With imagenet dataset size (224,224,3)

# %%
import keras
import cv2
import numpy as np
from keras.datasets import cifar10, cifar100
from keras.models import Model
from keras.layers import Input, Dense, Dropout, Activation, Add, Flatten
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from keras.initializers import glorot_uniform
from keras.regularizers import l2
from keras.layers.merge import concatenate
from keras.layers.normalization import BatchNormalization
from keras import optimizers
# Out:
# Using TensorFlow backend.

# %%
c10_class_name = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
c100_class_name = ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 
                   'camel', 'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 
                   'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 
                   'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse','mushroom', 'oak_tree', 'orange', 'orchid', 
                   'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 
                   'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 
                   'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 
                   'willow_tree', 'wolf', 'woman', 'worm']

# %%
def preprocess_image(X, image_height=224, image_width=224):
    X_resize = []
    for i in range(len(X)):
        #X[i] = X[i] / 255.0
        X_resize.append(cv2.resize(X[i], (image_height, image_width)))
    return np.asarray(X_resize)

# %%
def inception_module(X, f1, f2_in, f2_out, f3_in, f3_out, f4_out, stage, block):
    
    name_sb = str(stage) + str(block)
    
    # 1x1 conv
    conv1 = Conv2D(f1, (1,1), padding='same', activation='relu', name = 'conv_tower1_' + name_sb)(X)
    # 3x3 conv
    conv3 = Conv2D(f2_in, (1,1), padding='same', activation='relu', name = 'conv_tower2_1_' + name_sb)(X)
    conv3 = Conv2D(f2_out, (3,3), padding='same', activation='relu', name = 'conv_tower2_2' + name_sb)(conv3)
    # 5x5 conv
    conv5 = Conv2D(f3_in, (1,1), padding='same', activation='relu', name = 'conv_tower3_1_' + name_sb)(X)
    conv5 = Conv2D(f3_out, (5,5), padding='same', activation='relu', name = 'conv_tower3_2_' + name_sb)(conv5)
    # 3x3 max pooling
    pool = MaxPooling2D((3,3), strides=(1,1), padding='same', name = 'mpool_tower4_' + name_sb)(X)
    pool = Conv2D(f4_out, (1,1), padding='same', activation='relu', name = 'conv_tower4_' + name_sb)(pool)
    
    # concatenate filters
    layer_out = concatenate([conv1, conv3, conv5, pool], axis=-1)
    
    return layer_out

# %%
def auxiliary(x, classes, name=None):
    
    layer = AveragePooling2D(pool_size=(5,5), strides=3, padding='valid')(x)
    layer = Conv2D(filters=128, kernel_size=(1,1), strides=1, padding='same', activation='relu')(layer)
    layer = Flatten()(layer)
    layer = Dense(units=1024, activation='relu')(layer)
    layer = Dense(units=1000, activation='relu')(layer)
    layer = Dense(units=classes, activation='softmax', name=name)(layer)
    
    return layer

# %%
def googlenet(input_shape, classes):
    
    X_input = Input(input_shape)

    # Zero-Padding
    X = X_input #ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), padding = 'same', name = 'conv_pre_inception_1', kernel_initializer = glorot_uniform(seed=0))(X)
    #X = BatchNormalization(axis = 3, name = 'bn_pre_inception_1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2), padding = 'same', name = 'mpool_pre_inception_1')(X)
    
    # Stage 2
    X = Conv2D(192, (3, 3), strides = (1, 1), padding = 'same', name = 'conv_pre_inception_2', kernel_initializer = glorot_uniform(seed=0))(X)
    #X = BatchNormalization(axis = 3, name = 'bn_pre_inception_2')(X)
    X = Activation('relu')(X)
    X = Conv2D(192, (3, 3), strides = (1, 1), padding = 'same', name = 'conv_pre_inception_3', kernel_initializer = glorot_uniform(seed=0))(X)
    #X = BatchNormalization(axis = 3, name = 'bn_pre_inception_3')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2), padding = 'same', name = 'mpool_pre_inception_2')(X)
    
    # Stage 3
    X = inception_module(X, 64, 96, 128, 16, 32, 32, 3, 'a')
    X = inception_module(X, 128, 128, 192, 32, 96, 64, 3, 'b')
    X = MaxPooling2D((3, 3), strides=(2, 2), padding = 'same', name = 'mpool_inception_3')(X)
    
    # Stage 4
    X = inception_module(X, 192, 96, 208, 16, 48, 64, 4, 'a')
    aux1  = auxiliary(X, classes, name='aux1')
    X = inception_module(X, 160, 112, 224, 24, 64, 64, 4, 'b')
    X = inception_module(X, 128, 128, 256, 24, 24, 64, 4, 'c')
    X = inception_module(X, 112, 144, 288, 32, 64, 64, 4, 'd')
    aux2  = auxiliary(X, classes, name='aux2')
    X = inception_module(X, 256, 120, 320, 32, 128, 128, 4, 'e')
    X = MaxPooling2D((3, 3), strides=(2, 2), padding = 'same', name = 'mpool_inception_4')(X)
    
    # Stage 5
    X = inception_module(X, 256, 160, 320, 32, 128, 128, 5, 'a')
    X = inception_module(X, 384, 192, 384, 48, 128, 128, 5, 'b')
    X = AveragePooling2D((7, 7), strides=(1, 1), name = 'apool_inception_5')(X)
    
    # Stage 6
    X = Dropout(0.4)(X)
    X = Flatten()(X)
    X = Dense(1000, activation='relu', kernel_initializer = glorot_uniform(seed=0))(X)
    main = Dense(classes, activation='softmax', name='main', kernel_initializer = glorot_uniform(seed=0))(X)
    
    aux1 = keras.layers.Lambda(lambda x: x * 0.3)(aux1)                                         
    aux2 = keras.layers.Lambda(lambda x: x * 0.3)(aux2)                                         
    totalloss = keras.layers.Add()([aux1, aux2, main])                     
    
    inceptionv1 = Model(inputs = X_input, outputs = [totalloss], name='InceptionV1')            
    opt = keras.optimizers.Adam(learning_rate=0.0001)
    inceptionv1.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
    
    return inceptionv1

# %% [markdown]
# ### CIFAR - 10

# %%
# Load data
(c10_x_train_orig, c10_y_train_orig), (c10_x_test_orig, c10_y_test_orig) = cifar10.load_data()

# Pre-processing X
c10_x_train = preprocess_image(c10_x_train_orig)
c10_x_test = preprocess_image(c10_x_test_orig)

# Hyper-parameters
c10_epochs = 25
c10_batch_size = 64
c10_num_classes = 10
c10_input_shape = c10_x_train.shape[1:]

# Pre-processing Y
c10_y_train = keras.utils.to_categorical(c10_y_train_orig, c10_num_classes)
c10_y_test = keras.utils.to_categorical(c10_y_test_orig, c10_num_classes)

print(c10_x_train.shape, c10_x_test.shape, c10_y_train.shape, c10_y_test.shape)
# Out:
# (50000, 224, 224, 3) (10000, 224, 224, 3) (50000, 10) (10000, 10)

# %%
c10_googlenet = googlenet(c10_input_shape, c10_num_classes)
c10_googlenet.summary()
# Out:
# Model: "InceptionV1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv_pre_inception_1 (Conv2D)   (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           conv_pre_inception_1[0][0]
# __________________________________________________________________________________________________
# mpool_pre_inception_1 (MaxPooli (None, 56, 56, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv_pre_inception_2 (Conv2D)   (None, 56, 56, 192)  110784      mpool_pre_inception_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 192)  0           conv_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_pre_inception_3 (Conv2D)   (None, 56, 56, 192)  331968      activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 192)  0           conv_pre_inception_3[0][0]
# __________________________________________________________________________________________________
# mpool_pre_inception_2 (MaxPooli (None, 28, 28, 192)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_3a (Conv2D)       (None, 28, 28, 96)   18528       mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_3a (Conv2D)       (None, 28, 28, 16)   3088        mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_3a (MaxPooling2D)  (None, 28, 28, 192)  0           mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_tower1_3a (Conv2D)         (None, 28, 28, 64)   12352       mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_tower2_23a (Conv2D)        (None, 28, 28, 128)  110720      conv_tower2_1_3a[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_3a (Conv2D)       (None, 28, 28, 32)   12832       conv_tower3_1_3a[0][0]
# __________________________________________________________________________________________________
# conv_tower4_3a (Conv2D)         (None, 28, 28, 32)   6176        mpool_tower4_3a[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 256)  0           conv_tower1_3a[0][0]
#                                                                  conv_tower2_23a[0][0]
#                                                                  conv_tower3_2_3a[0][0]
#                                                                  conv_tower4_3a[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_3b (Conv2D)       (None, 28, 28, 128)  32896       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_3b (Conv2D)       (None, 28, 28, 32)   8224        concatenate_1[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_3b (MaxPooling2D)  (None, 28, 28, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv_tower1_3b (Conv2D)         (None, 28, 28, 128)  32896       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv_tower2_23b (Conv2D)        (None, 28, 28, 192)  221376      conv_tower2_1_3b[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_3b (Conv2D)       (None, 28, 28, 96)   76896       conv_tower3_1_3b[0][0]
# __________________________________________________________________________________________________
# conv_tower4_3b (Conv2D)         (None, 28, 28, 64)   16448       mpool_tower4_3b[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 28, 28, 480)  0           conv_tower1_3b[0][0]
#                                                                  conv_tower2_23b[0][0]
#                                                                  conv_tower3_2_3b[0][0]
#                                                                  conv_tower4_3b[0][0]
# __________________________________________________________________________________________________
# mpool_inception_3 (MaxPooling2D (None, 14, 14, 480)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4a (Conv2D)       (None, 14, 14, 96)   46176       mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4a (Conv2D)       (None, 14, 14, 16)   7696        mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4a (MaxPooling2D)  (None, 14, 14, 480)  0           mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4a (Conv2D)         (None, 14, 14, 192)  92352       mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24a (Conv2D)        (None, 14, 14, 208)  179920      conv_tower2_1_4a[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4a (Conv2D)       (None, 14, 14, 48)   19248       conv_tower3_1_4a[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4a (Conv2D)         (None, 14, 14, 64)   30784       mpool_tower4_4a[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 14, 512)  0           conv_tower1_4a[0][0]
#                                                                  conv_tower2_24a[0][0]
#                                                                  conv_tower3_2_4a[0][0]
#                                                                  conv_tower4_4a[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4b (Conv2D)       (None, 14, 14, 112)  57456       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4b (Conv2D)       (None, 14, 14, 24)   12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4b (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4b (Conv2D)         (None, 14, 14, 160)  82080       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24b (Conv2D)        (None, 14, 14, 224)  226016      conv_tower2_1_4b[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4b (Conv2D)       (None, 14, 14, 64)   38464       conv_tower3_1_4b[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4b (Conv2D)         (None, 14, 14, 64)   32832       mpool_tower4_4b[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 14, 14, 512)  0           conv_tower1_4b[0][0]
#                                                                  conv_tower2_24b[0][0]
#                                                                  conv_tower3_2_4b[0][0]
#                                                                  conv_tower4_4b[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4c (Conv2D)       (None, 14, 14, 128)  65664       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4c (Conv2D)       (None, 14, 14, 24)   12312       concatenate_4[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4c (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4c (Conv2D)         (None, 14, 14, 128)  65664       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24c (Conv2D)        (None, 14, 14, 256)  295168      conv_tower2_1_4c[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4c (Conv2D)       (None, 14, 14, 24)   14424       conv_tower3_1_4c[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4c (Conv2D)         (None, 14, 14, 64)   32832       mpool_tower4_4c[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 14, 14, 472)  0           conv_tower1_4c[0][0]
#                                                                  conv_tower2_24c[0][0]
#                                                                  conv_tower3_2_4c[0][0]
#                                                                  conv_tower4_4c[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4d (Conv2D)       (None, 14, 14, 144)  68112       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4d (Conv2D)       (None, 14, 14, 32)   15136       concatenate_5[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4d (MaxPooling2D)  (None, 14, 14, 472)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4d (Conv2D)         (None, 14, 14, 112)  52976       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24d (Conv2D)        (None, 14, 14, 288)  373536      conv_tower2_1_4d[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4d (Conv2D)       (None, 14, 14, 64)   51264       conv_tower3_1_4d[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4d (Conv2D)         (None, 14, 14, 64)   30272       mpool_tower4_4d[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 14, 14, 528)  0           conv_tower1_4d[0][0]
#                                                                  conv_tower2_24d[0][0]
#                                                                  conv_tower3_2_4d[0][0]
#                                                                  conv_tower4_4d[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4e (Conv2D)       (None, 14, 14, 120)  63480       concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4e (Conv2D)       (None, 14, 14, 32)   16928       concatenate_6[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4e (MaxPooling2D)  (None, 14, 14, 528)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4e (Conv2D)         (None, 14, 14, 256)  135424      concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24e (Conv2D)        (None, 14, 14, 320)  345920      conv_tower2_1_4e[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4e (Conv2D)       (None, 14, 14, 128)  102528      conv_tower3_1_4e[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4e (Conv2D)         (None, 14, 14, 128)  67712       mpool_tower4_4e[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 14, 14, 832)  0           conv_tower1_4e[0][0]
#                                                                  conv_tower2_24e[0][0]
#                                                                  conv_tower3_2_4e[0][0]
#                                                                  conv_tower4_4e[0][0]
# __________________________________________________________________________________________________
# mpool_inception_4 (MaxPooling2D (None, 7, 7, 832)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_5a (Conv2D)       (None, 7, 7, 160)    133280      mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_5a (Conv2D)       (None, 7, 7, 32)     26656       mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_5a (MaxPooling2D)  (None, 7, 7, 832)    0           mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# conv_tower1_5a (Conv2D)         (None, 7, 7, 256)    213248      mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# conv_tower2_25a (Conv2D)        (None, 7, 7, 320)    461120      conv_tower2_1_5a[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_5a (Conv2D)       (None, 7, 7, 128)    102528      conv_tower3_1_5a[0][0]
# __________________________________________________________________________________________________
# conv_tower4_5a (Conv2D)         (None, 7, 7, 128)    106624      mpool_tower4_5a[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 7, 7, 832)    0           conv_tower1_5a[0][0]
#                                                                  conv_tower2_25a[0][0]
#                                                                  conv_tower3_2_5a[0][0]
#                                                                  conv_tower4_5a[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_5b (Conv2D)       (None, 7, 7, 192)    159936      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_5b (Conv2D)       (None, 7, 7, 48)     39984       concatenate_8[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_5b (MaxPooling2D)  (None, 7, 7, 832)    0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 512)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 4, 4, 528)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower1_5b (Conv2D)         (None, 7, 7, 384)    319872      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv_tower2_25b (Conv2D)        (None, 7, 7, 384)    663936      conv_tower2_1_5b[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_5b (Conv2D)       (None, 7, 7, 128)    153728      conv_tower3_1_5b[0][0]
# __________________________________________________________________________________________________
# conv_tower4_5b (Conv2D)         (None, 7, 7, 128)    106624      mpool_tower4_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 4, 4, 128)    65664       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 4, 4, 128)    67712       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 7, 7, 1024)   0           conv_tower1_5b[0][0]
#                                                                  conv_tower2_25b[0][0]
#                                                                  conv_tower3_2_5b[0][0]
#                                                                  conv_tower4_5b[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 2048)         0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# apool_inception_5 (AveragePooli (None, 1, 1, 1024)   0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1024)         2098176     flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1, 1, 1024)   0           apool_inception_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1000)         1025000     dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1000)         1025000     dense_3[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 1024)         0           dropout_1[0][0]
# __________________________________________________________________________________________________
# aux1 (Dense)                    (None, 10)           10010       dense_2[0][0]
# __________________________________________________________________________________________________
# aux2 (Dense)                    (None, 10)           10010       dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1000)         1025000     flatten_3[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 10)           0           aux1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 10)           0           aux2[0][0]
# __________________________________________________________________________________________________
# main (Dense)                    (None, 10)           10010       dense_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 10)           0           lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  main[0][0]
# ==================================================================================================
# Total params: 13,561,638
# Trainable params: 13,561,638
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
c10_googlenet.fit(c10_x_train, c10_y_train, validation_data = (c10_x_test, c10_y_test), epochs = c10_epochs, batch_size = c10_batch_size)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 209s 4ms/step - loss: 1.6221 - accuracy: 0.4066 - val_loss: 1.3662 - val_accuracy: 0.4963
# Epoch 2/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 1.1825 - accuracy: 0.5763 - val_loss: 1.0605 - val_accuracy: 0.6155
# Epoch 3/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.9604 - accuracy: 0.6591 - val_loss: 0.9588 - val_accuracy: 0.6695
# Epoch 4/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.8050 - accuracy: 0.7151 - val_loss: 0.8500 - val_accuracy: 0.6986
# Epoch 5/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.6916 - accuracy: 0.7519 - val_loss: 0.7261 - val_accuracy: 0.7541
# Epoch 6/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.6009 - accuracy: 0.7826 - val_loss: 0.7477 - val_accuracy: 0.7421
# Epoch 7/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.5296 - accuracy: 0.8060 - val_loss: 0.6489 - val_accuracy: 0.7757
# Epoch 8/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.4611 - accuracy: 0.8288 - val_loss: 0.6585 - val_accuracy: 0.7764
# Epoch 9/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.4151 - accuracy: 0.8426 - val_loss: 0.6059 - val_accuracy: 0.8050
# Epoch 10/25
# 50000/50000 [==============================] - 199s 4ms/step - loss: 0.3626 - accuracy: 0.8585 - val_loss: 0.6447 - val_accuracy: 0.7961
# Epoch 11/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.2950 - accuracy: 0.8803 - val_loss: 0.6270 - val_accuracy: 0.8021
# Epoch 13/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.2642 - accuracy: 0.8924 - val_loss: 0.6507 - val_accuracy: 0.8078
# Epoch 14/25
# 50000/50000 [==============================] - 199s 4ms/step - loss: 0.2411 - accuracy: 0.8994 - val_loss: 0.6587 - val_accuracy: 0.7970
# Epoch 15/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.2266 - accuracy: 0.9063 - val_loss: 0.6289 - val_accuracy: 0.8254
# Epoch 16/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.2171 - accuracy: 0.9080 - val_loss: 0.6148 - val_accuracy: 0.8291
# Epoch 17/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.2045 - accuracy: 0.9113 - val_loss: 0.7178 - val_accuracy: 0.8091
# Epoch 18/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.1812 - accuracy: 0.9233 - val_loss: 0.7219 - val_accuracy: 0.8189
# Epoch 19/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.1708 - accuracy: 0.9269 - val_loss: 0.7030 - val_accuracy: 0.8169
# Epoch 20/25
# 50000/50000 [==============================] - 199s 4ms/step - loss: 0.1767 - accuracy: 0.9253 - val_loss: 0.6399 - val_accuracy: 0.8210
# Epoch 21/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.1560 - accuracy: 0.9300 - val_loss: 0.6844 - val_accuracy: 0.8226
# Epoch 22/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.1482 - accuracy: 0.9359 - val_loss: 0.6965 - val_accuracy: 0.8259
# Epoch 23/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.1553 - accuracy: 0.9316 - val_loss: 0.6699 - val_accuracy: 0.8322
# Epoch 24/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.1232 - accuracy: 0.9457 - val_loss: 0.7224 - val_accuracy: 0.8307
# Epoch 25/25
# 50000/50000 [==============================] - 198s 4ms/step - loss: 0.1411 - accuracy: 0.9384 - val_loss: 0.6665 - val_accuracy: 0.8341

# %%
scores = c10_googlenet.evaluate(c10_x_test, c10_y_test)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 15s 2ms/step
# Test loss: 0.6665419538021088
# Test accuracy: 0.8341000080108643

# %%
predictions = {}
for i in range(c10_num_classes):
    index = np.where(c10_y_test_orig == i)
    slice_x_test = c10_x_test[index[0]]
    slice_y_test = c10_y_test[index[0]]
    scores = c10_googlenet.evaluate(slice_x_test, slice_y_test, verbose = 0)
    print('Class: ' + c10_class_name[i] + ' Test accuracy: ' + str(scores[1]))
    predictions[c10_class_name[i]] = str(scores[1])
# Out:
# Class: airplane Test accuracy: 0.8849999904632568
# Class: automobile Test accuracy: 0.8679999709129333
# Class: bird Test accuracy: 0.7940000295639038
# Class: cat Test accuracy: 0.7480000257492065
# Class: deer Test accuracy: 0.859000027179718
# Class: dog Test accuracy: 0.746999979019165
# Class: frog Test accuracy: 0.8930000066757202
# Class: horse Test accuracy: 0.8080000281333923
# Class: ship Test accuracy: 0.8999999761581421
# Class: truck Test accuracy: 0.8389999866485596

# %% [markdown]
# ### CIFAR - 100

# %%
# Load data
(c100_x_train_orig, c100_y_train_orig), (c100_x_test_orig, c100_y_test_orig) = cifar100.load_data()

# Pre-processing X
c100_x_train = preprocess_image(c100_x_train_orig)
c100_x_test = preprocess_image(c100_x_test_orig)

# Hyper-parameters
c100_epochs = 50
c100_batch_size = 128
c100_num_classes = 100
c100_input_shape = c100_x_train.shape[1:]

# Pre-processing Y
c100_y_train = keras.utils.to_categorical(c100_y_train_orig, c100_num_classes)
c100_y_test = keras.utils.to_categorical(c100_y_test_orig, c100_num_classes)

print(c100_x_train.shape, c100_y_train.shape, c100_x_test.shape, c100_y_test.shape)
# Out:
# (50000, 224, 224, 3) (50000, 100) (10000, 224, 224, 3) (10000, 100)

# %%
c100_googlenet = googlenet(c100_input_shape, c100_num_classes)
c100_googlenet.summary()
# Out:
# Model: "InceptionV1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv_pre_inception_1 (Conv2D)   (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           conv_pre_inception_1[0][0]
# __________________________________________________________________________________________________
# mpool_pre_inception_1 (MaxPooli (None, 56, 56, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv_pre_inception_2 (Conv2D)   (None, 56, 56, 192)  110784      mpool_pre_inception_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 56, 56, 192)  0           conv_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_pre_inception_3 (Conv2D)   (None, 56, 56, 192)  331968      activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 192)  0           conv_pre_inception_3[0][0]
# __________________________________________________________________________________________________
# mpool_pre_inception_2 (MaxPooli (None, 28, 28, 192)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_3a (Conv2D)       (None, 28, 28, 96)   18528       mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_3a (Conv2D)       (None, 28, 28, 16)   3088        mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_3a (MaxPooling2D)  (None, 28, 28, 192)  0           mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_tower1_3a (Conv2D)         (None, 28, 28, 64)   12352       mpool_pre_inception_2[0][0]
# __________________________________________________________________________________________________
# conv_tower2_23a (Conv2D)        (None, 28, 28, 128)  110720      conv_tower2_1_3a[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_3a (Conv2D)       (None, 28, 28, 32)   12832       conv_tower3_1_3a[0][0]
# __________________________________________________________________________________________________
# conv_tower4_3a (Conv2D)         (None, 28, 28, 32)   6176        mpool_tower4_3a[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 28, 28, 256)  0           conv_tower1_3a[0][0]
#                                                                  conv_tower2_23a[0][0]
#                                                                  conv_tower3_2_3a[0][0]
#                                                                  conv_tower4_3a[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_3b (Conv2D)       (None, 28, 28, 128)  32896       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_3b (Conv2D)       (None, 28, 28, 32)   8224        concatenate_1[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_3b (MaxPooling2D)  (None, 28, 28, 256)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv_tower1_3b (Conv2D)         (None, 28, 28, 128)  32896       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv_tower2_23b (Conv2D)        (None, 28, 28, 192)  221376      conv_tower2_1_3b[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_3b (Conv2D)       (None, 28, 28, 96)   76896       conv_tower3_1_3b[0][0]
# __________________________________________________________________________________________________
# conv_tower4_3b (Conv2D)         (None, 28, 28, 64)   16448       mpool_tower4_3b[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 28, 28, 480)  0           conv_tower1_3b[0][0]
#                                                                  conv_tower2_23b[0][0]
#                                                                  conv_tower3_2_3b[0][0]
#                                                                  conv_tower4_3b[0][0]
# __________________________________________________________________________________________________
# mpool_inception_3 (MaxPooling2D (None, 14, 14, 480)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4a (Conv2D)       (None, 14, 14, 96)   46176       mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4a (Conv2D)       (None, 14, 14, 16)   7696        mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4a (MaxPooling2D)  (None, 14, 14, 480)  0           mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4a (Conv2D)         (None, 14, 14, 192)  92352       mpool_inception_3[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24a (Conv2D)        (None, 14, 14, 208)  179920      conv_tower2_1_4a[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4a (Conv2D)       (None, 14, 14, 48)   19248       conv_tower3_1_4a[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4a (Conv2D)         (None, 14, 14, 64)   30784       mpool_tower4_4a[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 14, 512)  0           conv_tower1_4a[0][0]
#                                                                  conv_tower2_24a[0][0]
#                                                                  conv_tower3_2_4a[0][0]
#                                                                  conv_tower4_4a[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4b (Conv2D)       (None, 14, 14, 112)  57456       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4b (Conv2D)       (None, 14, 14, 24)   12312       concatenate_3[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4b (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4b (Conv2D)         (None, 14, 14, 160)  82080       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24b (Conv2D)        (None, 14, 14, 224)  226016      conv_tower2_1_4b[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4b (Conv2D)       (None, 14, 14, 64)   38464       conv_tower3_1_4b[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4b (Conv2D)         (None, 14, 14, 64)   32832       mpool_tower4_4b[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 14, 14, 512)  0           conv_tower1_4b[0][0]
#                                                                  conv_tower2_24b[0][0]
#                                                                  conv_tower3_2_4b[0][0]
#                                                                  conv_tower4_4b[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4c (Conv2D)       (None, 14, 14, 128)  65664       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4c (Conv2D)       (None, 14, 14, 24)   12312       concatenate_4[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4c (MaxPooling2D)  (None, 14, 14, 512)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4c (Conv2D)         (None, 14, 14, 128)  65664       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24c (Conv2D)        (None, 14, 14, 256)  295168      conv_tower2_1_4c[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4c (Conv2D)       (None, 14, 14, 24)   14424       conv_tower3_1_4c[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4c (Conv2D)         (None, 14, 14, 64)   32832       mpool_tower4_4c[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 14, 14, 472)  0           conv_tower1_4c[0][0]
#                                                                  conv_tower2_24c[0][0]
#                                                                  conv_tower3_2_4c[0][0]
#                                                                  conv_tower4_4c[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4d (Conv2D)       (None, 14, 14, 144)  68112       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4d (Conv2D)       (None, 14, 14, 32)   15136       concatenate_5[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4d (MaxPooling2D)  (None, 14, 14, 472)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4d (Conv2D)         (None, 14, 14, 112)  52976       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24d (Conv2D)        (None, 14, 14, 288)  373536      conv_tower2_1_4d[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4d (Conv2D)       (None, 14, 14, 64)   51264       conv_tower3_1_4d[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4d (Conv2D)         (None, 14, 14, 64)   30272       mpool_tower4_4d[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 14, 14, 528)  0           conv_tower1_4d[0][0]
#                                                                  conv_tower2_24d[0][0]
#                                                                  conv_tower3_2_4d[0][0]
#                                                                  conv_tower4_4d[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_4e (Conv2D)       (None, 14, 14, 120)  63480       concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_4e (Conv2D)       (None, 14, 14, 32)   16928       concatenate_6[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_4e (MaxPooling2D)  (None, 14, 14, 528)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower1_4e (Conv2D)         (None, 14, 14, 256)  135424      concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower2_24e (Conv2D)        (None, 14, 14, 320)  345920      conv_tower2_1_4e[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_4e (Conv2D)       (None, 14, 14, 128)  102528      conv_tower3_1_4e[0][0]
# __________________________________________________________________________________________________
# conv_tower4_4e (Conv2D)         (None, 14, 14, 128)  67712       mpool_tower4_4e[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 14, 14, 832)  0           conv_tower1_4e[0][0]
#                                                                  conv_tower2_24e[0][0]
#                                                                  conv_tower3_2_4e[0][0]
#                                                                  conv_tower4_4e[0][0]
# __________________________________________________________________________________________________
# mpool_inception_4 (MaxPooling2D (None, 7, 7, 832)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_5a (Conv2D)       (None, 7, 7, 160)    133280      mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_5a (Conv2D)       (None, 7, 7, 32)     26656       mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_5a (MaxPooling2D)  (None, 7, 7, 832)    0           mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# conv_tower1_5a (Conv2D)         (None, 7, 7, 256)    213248      mpool_inception_4[0][0]
# __________________________________________________________________________________________________
# conv_tower2_25a (Conv2D)        (None, 7, 7, 320)    461120      conv_tower2_1_5a[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_5a (Conv2D)       (None, 7, 7, 128)    102528      conv_tower3_1_5a[0][0]
# __________________________________________________________________________________________________
# conv_tower4_5a (Conv2D)         (None, 7, 7, 128)    106624      mpool_tower4_5a[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 7, 7, 832)    0           conv_tower1_5a[0][0]
#                                                                  conv_tower2_25a[0][0]
#                                                                  conv_tower3_2_5a[0][0]
#                                                                  conv_tower4_5a[0][0]
# __________________________________________________________________________________________________
# conv_tower2_1_5b (Conv2D)       (None, 7, 7, 192)    159936      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv_tower3_1_5b (Conv2D)       (None, 7, 7, 48)     39984       concatenate_8[0][0]
# __________________________________________________________________________________________________
# mpool_tower4_5b (MaxPooling2D)  (None, 7, 7, 832)    0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 512)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 4, 4, 528)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv_tower1_5b (Conv2D)         (None, 7, 7, 384)    319872      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv_tower2_25b (Conv2D)        (None, 7, 7, 384)    663936      conv_tower2_1_5b[0][0]
# __________________________________________________________________________________________________
# conv_tower3_2_5b (Conv2D)       (None, 7, 7, 128)    153728      conv_tower3_1_5b[0][0]
# __________________________________________________________________________________________________
# conv_tower4_5b (Conv2D)         (None, 7, 7, 128)    106624      mpool_tower4_5b[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 4, 4, 128)    65664       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 4, 4, 128)    67712       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 7, 7, 1024)   0           conv_tower1_5b[0][0]
#                                                                  conv_tower2_25b[0][0]
#                                                                  conv_tower3_2_5b[0][0]
#                                                                  conv_tower4_5b[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 2048)         0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# apool_inception_5 (AveragePooli (None, 1, 1, 1024)   0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1024)         2098176     flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1, 1, 1024)   0           apool_inception_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1000)         1025000     dense_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1000)         1025000     dense_3[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 1024)         0           dropout_1[0][0]
# __________________________________________________________________________________________________
# aux1 (Dense)                    (None, 100)          100100      dense_2[0][0]
# __________________________________________________________________________________________________
# aux2 (Dense)                    (None, 100)          100100      dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1000)         1025000     flatten_3[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 100)          0           aux1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 100)          0           aux2[0][0]
# __________________________________________________________________________________________________
# main (Dense)                    (None, 100)          100100      dense_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 100)          0           lambda_1[0][0]
#                                                                  lambda_2[0][0]
#                                                                  main[0][0]
# ==================================================================================================
# Total params: 13,831,908
# Trainable params: 13,831,908
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
c100_googlenet.fit(c100_x_train, c100_y_train, validation_data = (c100_x_test, c100_y_test), epochs = c100_epochs, batch_size = c100_batch_size)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 206s 4ms/step - loss: 4.0188 - accuracy: 0.1003 - val_loss: 3.6347 - val_accuracy: 0.1662
# Epoch 2/50
# 50000/50000 [==============================] - 190s 4ms/step - loss: 3.4428 - accuracy: 0.1897 - val_loss: 3.2976 - val_accuracy: 0.2330
# Epoch 3/50
# 50000/50000 [==============================] - 188s 4ms/step - loss: 3.1181 - accuracy: 0.2486 - val_loss: 3.0506 - val_accuracy: 0.2577
# Epoch 4/50
# 50000/50000 [==============================] - 188s 4ms/step - loss: 2.8578 - accuracy: 0.3008 - val_loss: 2.8190 - val_accuracy: 0.3119
# Epoch 5/50
# 50000/50000 [==============================] - 188s 4ms/step - loss: 2.6238 - accuracy: 0.3448 - val_loss: 2.6741 - val_accuracy: 0.3236
# Epoch 6/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 2.4279 - accuracy: 0.3763 - val_loss: 2.5206 - val_accuracy: 0.3617
# Epoch 7/50
# 50000/50000 [==============================] - 188s 4ms/step - loss: 2.2398 - accuracy: 0.4139 - val_loss: 2.4552 - val_accuracy: 0.3762
# Epoch 8/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 2.0634 - accuracy: 0.4513 - val_loss: 2.3875 - val_accuracy: 0.3932
# Epoch 9/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 1.9004 - accuracy: 0.4822 - val_loss: 2.2649 - val_accuracy: 0.4194
# Epoch 10/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 1.7518 - accuracy: 0.5123 - val_loss: 2.2711 - val_accuracy: 0.4265
# Epoch 11/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 1.6252 - accuracy: 0.5338 - val_loss: 2.2296 - val_accuracy: 0.4325
# Epoch 12/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 1.5011 - accuracy: 0.5596 - val_loss: 2.2020 - val_accuracy: 0.4489
# Epoch 13/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 1.3969 - accuracy: 0.5751 - val_loss: 2.1995 - val_accuracy: 0.4596
# Epoch 14/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 1.3276 - accuracy: 0.5877 - val_loss: 2.2043 - val_accuracy: 0.4626
# Epoch 15/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 1.2533 - accuracy: 0.6024 - val_loss: 2.1907 - val_accuracy: 0.4664
# Epoch 16/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 1.1862 - accuracy: 0.6152 - val_loss: 2.2532 - val_accuracy: 0.4610
# Epoch 17/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 1.1247 - accuracy: 0.6278 - val_loss: 2.3292 - val_accuracy: 0.4670
# Epoch 18/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 1.0921 - accuracy: 0.6301 - val_loss: 2.2806 - val_accuracy: 0.4699
# Epoch 19/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 1.0478 - accuracy: 0.6421 - val_loss: 2.1756 - val_accuracy: 0.4881
# Epoch 20/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 0.9993 - accuracy: 0.6521 - val_loss: 2.2982 - val_accuracy: 0.4820
# Epoch 21/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 0.9495 - accuracy: 0.6616 - val_loss: 2.3269 - val_accuracy: 0.4881
# Epoch 22/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 0.9393 - accuracy: 0.6633 - val_loss: 2.3039 - val_accuracy: 0.4842
# Epoch 23/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 0.9022 - accuracy: 0.6754 - val_loss: 2.5227 - val_accuracy: 0.4815
# Epoch 24/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 0.8726 - accuracy: 0.6807 - val_loss: 2.3984 - val_accuracy: 0.5009
# Epoch 25/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 0.8277 - accuracy: 0.6936 - val_loss: 2.3530 - val_accuracy: 0.5004
# Epoch 26/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 0.8024 - accuracy: 0.7016 - val_loss: 2.5206 - val_accuracy: 0.4930
# Epoch 27/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 0.8015 - accuracy: 0.7037 - val_loss: 2.4929 - val_accuracy: 0.5001
# Epoch 28/50
# 50000/50000 [==============================] - 188s 4ms/step - loss: 0.7648 - accuracy: 0.7164 - val_loss: 2.5423 - val_accuracy: 0.5023
# Epoch 29/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.7517 - accuracy: 0.7203 - val_loss: 2.6039 - val_accuracy: 0.5000
# Epoch 30/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.7277 - accuracy: 0.7273 - val_loss: 2.6160 - val_accuracy: 0.5006
# Epoch 31/50
# 50000/50000 [==============================] - 186s 4ms/step - loss: 0.7190 - accuracy: 0.7318 - val_loss: 2.6320 - val_accuracy: 0.4938
# Epoch 32/50
# 50000/50000 [==============================] - 186s 4ms/step - loss: 0.7141 - accuracy: 0.7383 - val_loss: 2.6395 - val_accuracy: 0.5040
# Epoch 33/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.6786 - accuracy: 0.7467 - val_loss: 2.6147 - val_accuracy: 0.5173
# Epoch 34/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.6511 - accuracy: 0.7545 - val_loss: 2.6302 - val_accuracy: 0.5082
# Epoch 35/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.6541 - accuracy: 0.7557 - val_loss: 2.8460 - val_accuracy: 0.5005
# Epoch 36/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.6408 - accuracy: 0.7617 - val_loss: 2.8443 - val_accuracy: 0.5081
# Epoch 37/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.6173 - accuracy: 0.7698 - val_loss: 2.7253 - val_accuracy: 0.5127
# Epoch 38/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.6076 - accuracy: 0.7769 - val_loss: 2.7830 - val_accuracy: 0.5248
# Epoch 39/50
# 50000/50000 [==============================] - 189s 4ms/step - loss: 0.6040 - accuracy: 0.7752 - val_loss: 2.8207 - val_accuracy: 0.5064
# Epoch 40/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.6049 - accuracy: 0.7830 - val_loss: 2.7798 - val_accuracy: 0.5115
# Epoch 41/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.5817 - accuracy: 0.7880 - val_loss: 2.7369 - val_accuracy: 0.5083
# Epoch 42/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.5856 - accuracy: 0.7890 - val_loss: 2.7307 - val_accuracy: 0.5102
# Epoch 43/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.5657 - accuracy: 0.7974 - val_loss: 2.8035 - val_accuracy: 0.5125
# Epoch 44/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.5610 - accuracy: 0.7972 - val_loss: 3.0102 - val_accuracy: 0.5240
# Epoch 45/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.5385 - accuracy: 0.8027 - val_loss: 2.8407 - val_accuracy: 0.5116
# Epoch 46/50
# 50000/50000 [==============================] - 188s 4ms/step - loss: 0.5338 - accuracy: 0.8099 - val_loss: 2.9063 - val_accuracy: 0.5212
# Epoch 47/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.5289 - accuracy: 0.8118 - val_loss: 2.8399 - val_accuracy: 0.5141
# Epoch 48/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.5201 - accuracy: 0.8164 - val_loss: 2.9000 - val_accuracy: 0.5157
# Epoch 49/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.5226 - accuracy: 0.8151 - val_loss: 2.9194 - val_accuracy: 0.5275
# Epoch 50/50
# 50000/50000 [==============================] - 187s 4ms/step - loss: 0.5287 - accuracy: 0.8154 - val_loss: 2.9023 - val_accuracy: 0.5335

# %%
c100_googlenet.fit(c100_x_train, c100_y_train, validation_data = (c100_x_test, c100_y_test), epochs = c100_epochs, batch_size = c100_batch_size)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 204s 4ms/step - loss: 4.0177 - accuracy: 0.0995 - val_loss: 3.5848 - val_accuracy: 0.1714
# Epoch 2/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 3.4159 - accuracy: 0.1913 - val_loss: 3.2889 - val_accuracy: 0.2234
# Epoch 3/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 3.0912 - accuracy: 0.2552 - val_loss: 3.0067 - val_accuracy: 0.2699
# Epoch 4/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 2.8341 - accuracy: 0.3078 - val_loss: 2.7738 - val_accuracy: 0.3197
# Epoch 5/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 2.6042 - accuracy: 0.3509 - val_loss: 2.6086 - val_accuracy: 0.3477
# Epoch 6/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 2.3927 - accuracy: 0.3868 - val_loss: 2.5816 - val_accuracy: 0.3510
# Epoch 7/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 2.2091 - accuracy: 0.4236 - val_loss: 2.4609 - val_accuracy: 0.3828
# Epoch 8/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 2.0469 - accuracy: 0.4557 - val_loss: 2.3285 - val_accuracy: 0.4122
# Epoch 9/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 1.8918 - accuracy: 0.4853 - val_loss: 2.3684 - val_accuracy: 0.3889
# Epoch 10/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 1.7501 - accuracy: 0.5130 - val_loss: 2.2941 - val_accuracy: 0.4148
# Epoch 11/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 1.6248 - accuracy: 0.5354 - val_loss: 2.2081 - val_accuracy: 0.4373
# Epoch 12/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 1.5106 - accuracy: 0.5547 - val_loss: 2.1741 - val_accuracy: 0.4470
# Epoch 13/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 1.4230 - accuracy: 0.5703 - val_loss: 2.2695 - val_accuracy: 0.4418
# Epoch 14/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 1.3502 - accuracy: 0.5823 - val_loss: 2.1312 - val_accuracy: 0.4615
# Epoch 15/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 1.2797 - accuracy: 0.5940 - val_loss: 2.1737 - val_accuracy: 0.4576
# Epoch 16/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 1.2197 - accuracy: 0.6070 - val_loss: 2.1434 - val_accuracy: 0.4732
# Epoch 17/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 1.1610 - accuracy: 0.6164 - val_loss: 2.1797 - val_accuracy: 0.4722
# Epoch 18/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 1.1061 - accuracy: 0.6259 - val_loss: 2.3521 - val_accuracy: 0.4534
# Epoch 19/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 1.0622 - accuracy: 0.6382 - val_loss: 2.2787 - val_accuracy: 0.4682
# Epoch 20/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 1.0131 - accuracy: 0.6466 - val_loss: 2.3199 - val_accuracy: 0.4751
# Epoch 21/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 0.9826 - accuracy: 0.6535 - val_loss: 2.3146 - val_accuracy: 0.4884
# Epoch 22/25
# 50000/50000 [==============================] - 193s 4ms/step - loss: 0.9406 - accuracy: 0.6608 - val_loss: 2.3341 - val_accuracy: 0.4800
# Epoch 23/25
#   384/50000 [..............................] - ETA: 2:59 - loss: 0.9521 - accuracy: 0.6745

# %%
scores = c100_googlenet.evaluate(c100_x_test, c100_y_test)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 15s 2ms/step
# Test loss: 2.9023271533966066
# Test accuracy: 0.5335000157356262

# %%
predictions = {}
for i in range(c100_num_classes):
    index = np.where(c100_y_test_orig == i)
    slice_x_test = c100_x_test[index[0]]
    slice_y_test = c100_y_test[index[0]]
    scores = c100_googlenet.evaluate(slice_x_test, slice_y_test, verbose = 0)
    print('Class: ' + c100_class_name[i] + ' Test accuracy: ' + str(scores[1]))
    predictions[c100_class_name[i]] = str(scores[1])
# Out:
# Class: apple Test accuracy: 0.8299999833106995
# Class: aquarium_fish Test accuracy: 0.6899999976158142
# Class: baby Test accuracy: 0.4099999964237213
# Class: bear Test accuracy: 0.3400000035762787
# Class: beaver Test accuracy: 0.3799999952316284
# Class: bed Test accuracy: 0.4699999988079071
# Class: bee Test accuracy: 0.7400000095367432
# Class: beetle Test accuracy: 0.6100000143051147
# Class: bicycle Test accuracy: 0.6899999976158142
# Class: bottle Test accuracy: 0.5799999833106995
# Class: bowl Test accuracy: 0.30000001192092896
# Class: boy Test accuracy: 0.38999998569488525
# Class: bridge Test accuracy: 0.5899999737739563
# Class: bus Test accuracy: 0.4300000071525574
# Class: butterfly Test accuracy: 0.4099999964237213
# Class: camel Test accuracy: 0.5099999904632568
# Class: can Test accuracy: 0.5699999928474426
# Class: castle Test accuracy: 0.699999988079071
# Class: caterpillar Test accuracy: 0.28999999165534973
# Class: cattle Test accuracy: 0.4300000071525574
# Class: chair Test accuracy: 0.7699999809265137
# Class: chimpanzee Test accuracy: 0.5899999737739563
# Class: clock Test accuracy: 0.47999998927116394
# Class: cloud Test accuracy: 0.75
# Class: cockroach Test accuracy: 0.6700000166893005
# Class: couch Test accuracy: 0.3700000047683716
# Class: crab Test accuracy: 0.33000001311302185
# Class: crocodile Test accuracy: 0.23999999463558197
# Class: cup Test accuracy: 0.5099999904632568
# Class: dinosaur Test accuracy: 0.4099999964237213
# Class: dolphin Test accuracy: 0.47999998927116394
# Class: elephant Test accuracy: 0.550000011920929
# Class: flatfish Test accuracy: 0.47999998927116394
# Class: forest Test accuracy: 0.5199999809265137
# Class: fox Test accuracy: 0.5199999809265137
# Class: girl Test accuracy: 0.5799999833106995
# Class: hamster Test accuracy: 0.7099999785423279
# Class: house Test accuracy: 0.4699999988079071
# Class: kangaroo Test accuracy: 0.36000001430511475
# Class: keyboard Test accuracy: 0.7300000190734863
# Class: lamp Test accuracy: 0.5099999904632568
# Class: lawn_mower Test accuracy: 0.7200000286102295
# Class: leopard Test accuracy: 0.6200000047683716
# Class: lion Test accuracy: 0.699999988079071
# Class: lizard Test accuracy: 0.28999999165534973
# Class: lobster Test accuracy: 0.3700000047683716
# Class: man Test accuracy: 0.3199999928474426
# Class: maple_tree Test accuracy: 0.550000011920929
# Class: motorcycle Test accuracy: 0.800000011920929
# Class: mountain Test accuracy: 0.7099999785423279
# Class: mouse Test accuracy: 0.5400000214576721
# Class: mushroom Test accuracy: 0.5
# Class: oak_tree Test accuracy: 0.8500000238418579
# Class: orange Test accuracy: 0.7900000214576721
# Class: orchid Test accuracy: 0.5699999928474426
# Class: otter Test accuracy: 0.2199999988079071
# Class: palm_tree Test accuracy: 0.7300000190734863
# Class: pear Test accuracy: 0.5
# Class: pickup_truck Test accuracy: 0.5699999928474426
# Class: pine_tree Test accuracy: 0.47999998927116394
# Class: plain Test accuracy: 0.7599999904632568
# Class: plate Test accuracy: 0.5799999833106995
# Class: poppy Test accuracy: 0.5799999833106995
# Class: porcupine Test accuracy: 0.4099999964237213
# Class: possum Test accuracy: 0.23999999463558197
# Class: rabbit Test accuracy: 0.25999999046325684
# Class: raccoon Test accuracy: 0.6100000143051147
# Class: ray Test accuracy: 0.44999998807907104
# Class: road Test accuracy: 0.8500000238418579
# Class: rocket Test accuracy: 0.7699999809265137
# Class: rose Test accuracy: 0.5400000214576721
# Class: sea Test accuracy: 0.7699999809265137
# Class: seal Test accuracy: 0.20999999344348907
# Class: shark Test accuracy: 0.38999998569488525
# Class: shrew Test accuracy: 0.3400000035762787
# Class: skunk Test accuracy: 0.6800000071525574
# Class: skyscraper Test accuracy: 0.8100000023841858
# Class: snail Test accuracy: 0.4000000059604645
# Class: snake Test accuracy: 0.44999998807907104
# Class: spider Test accuracy: 0.38999998569488525
# Class: squirrel Test accuracy: 0.25
# Class: streetcar Test accuracy: 0.6399999856948853
# Class: sunflower Test accuracy: 0.7699999809265137
# Class: sweet_pepper Test accuracy: 0.5199999809265137
# Class: table Test accuracy: 0.4000000059604645
# Class: tank Test accuracy: 0.6000000238418579
# Class: telephone Test accuracy: 0.49000000953674316
# Class: television Test accuracy: 0.6000000238418579
# Class: tiger Test accuracy: 0.699999988079071
# Class: tractor Test accuracy: 0.6100000143051147
# Class: train Test accuracy: 0.5899999737739563
# Class: trout Test accuracy: 0.5400000214576721
# Class: tulip Test accuracy: 0.49000000953674316
# Class: turtle Test accuracy: 0.20999999344348907
# Class: wardrobe Test accuracy: 0.8100000023841858
# Class: whale Test accuracy: 0.6299999952316284
# Class: willow_tree Test accuracy: 0.3400000035762787
# Class: wolf Test accuracy: 0.47999998927116394
# Class: woman Test accuracy: 0.3799999952316284
# Class: worm Test accuracy: 0.5899999737739563
